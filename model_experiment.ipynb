# %% [markdown]
# ## imports and other stuff

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# For MLflow tracking
import mlflow
import mlflow.sklearn
import mlflow.xgboost

# Use both environment variables and explicit authentication
os.environ["MLFLOW_TRACKING_URI"] = "https://dagshub.com/qetibakh/ML-Homework1.mlflow/"
os.environ["MLFLOW_TRACKING_USERNAME"] = "qetibakh"
os.environ["MLFLOW_TRACKING_PASSWORD"] = "5d5729711347a10a69c47eea029df715cc67e1ce"

# Test connection
print("MLflow tracking URI:", mlflow.get_tracking_uri())

# Load data
train_data = pd.read_csv("data/train.csv")
test_data = pd.read_csv("data/test.csv")

print(f"Training data shape: {train_data.shape}")
print(f"Test data shape: {test_data.shape}")

# Save original copies for reference
train_original = train_data.copy()
test_original = test_data.copy()
# Out:
# MLflow tracking URI: https://dagshub.com/qetibakh/ML-Homework1.mlflow/
# Training data shape: (1460, 81)
# Test data shape: (1459, 80)

# %% [markdown]
# ## cleaning

# %%
# Start MLflow run for cleaning
if mlflow.active_run():
    mlflow.end_run()
mlflow.start_run(run_name="data_cleaning")

# Function to log cleaning steps
def log_cleaning_step(description, affected_columns, technique):
    mlflow.log_param(f"cleaning_step_{description}_columns", str(affected_columns))
    mlflow.log_param(f"cleaning_step_{description}_technique", technique)

# Combine train and test for preprocessing
all_data = pd.concat([train_data.drop('SalePrice', axis=1), test_data])
print(f"Combined data shape: {all_data.shape}")

# Identify numerical and categorical features
num_features = all_data.select_dtypes(include=[np.number]).columns
cat_features = all_data.select_dtypes(include=['object']).columns

# Handle missing numerical data
numerical_na_cols = all_data[num_features].isnull().sum()[all_data[num_features].isnull().sum() > 0].index.tolist()
print(f"Numerical features with missing values: {numerical_na_cols}")

for col in numerical_na_cols:
    # Custom handling for each column with missing values
    if "garage" in col.lower() or "bsmt" in col.lower():
        # These are likely 0 if missing (no garage/basement)
        all_data[col].fillna(0, inplace=True)
        log_cleaning_step(f"fill_na_{col}", col, "fill_with_zero_as_feature_absent")
    else:
        # Fill with median for other numerical features
        all_data[col].fillna(all_data[col].median(), inplace=True)
        log_cleaning_step(f"fill_na_{col}", col, "fill_with_median")

# Handle missing categorical data
categorical_na_cols = all_data[cat_features].isnull().sum()[all_data[cat_features].isnull().sum() > 0].index.tolist()
print(f"Categorical features with missing values: {categorical_na_cols}")

for col in categorical_na_cols:
    if col in ["Alley", "PoolQC", "Fence", "MiscFeature"]:
        # These are often NA because the feature doesn't exist
        all_data[col].fillna("None", inplace=True)
        log_cleaning_step(f"fill_na_{col}", col, "fill_with_None_as_feature_absent")
    elif "garage" in col.lower() or "bsmt" in col.lower():
        # If these are missing, likely no garage/basement
        all_data[col].fillna("None", inplace=True)
        log_cleaning_step(f"fill_na_{col}", col, "fill_with_None_as_feature_absent")
    else:
        # For other categorical features, use mode
        all_data[col].fillna(all_data[col].mode()[0], inplace=True)
        log_cleaning_step(f"fill_na_{col}", col, "fill_with_mode")

# Check for remaining missing values
missing_after = all_data.isnull().sum().sum()
if missing_after > 0:
    print("Columns with remaining missing values:")
    print(all_data.isnull().sum()[all_data.isnull().sum() > 0])

    # Fill any remaining NaN values with appropriate values
    # For numeric columns, use median
    num_cols = all_data.select_dtypes(include=[np.number]).columns
    for col in num_cols:
        if all_data[col].isnull().sum() > 0:
            all_data[col] = all_data[col].fillna(all_data[col].median())
            print(f"Filled NaN values in numeric column {col} with median")

    # For categorical columns, use mode
    cat_cols = all_data.select_dtypes(include=['object']).columns
    for col in cat_cols:
        if all_data[col].isnull().sum() > 0:
            all_data[col] = all_data[col].fillna(all_data[col].mode()[0])
            print(f"Filled NaN values in categorical column {col} with mode")

# Final verification
assert all_data.isnull().sum().sum() == 0, "There are still missing values after cleaning!"
print("All missing values have been handled successfully.")

# End cleaning MLflow run
mlflow.end_run()
# Out:
# Combined data shape: (2919, 80)
# Numerical features with missing values: ['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt', 'GarageCars', 'GarageArea']
# Categorical features with missing values: ['MSZoning', 'Alley', 'Utilities', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType']
# All missing values have been handled successfully.
# 🏃 View run data_cleaning at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/f1ba8f56753e409ea55373c418e3bd7e
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0

# %% [markdown]
# ## feature engineering

# %%
# Start MLflow run for feature engineering
if mlflow.active_run():
    mlflow.end_run()
mlflow.start_run(run_name="feature_engineering")

# Function to log feature engineering steps
def log_feature_eng_step(description, technique, affected_columns=None, created_columns=None):
    if affected_columns:
        mlflow.log_param(f"fe_step_{description}_affected", str(affected_columns))
    if created_columns:
        mlflow.log_param(f"fe_step_{description}_created", str(created_columns))
    mlflow.log_param(f"fe_step_{description}_technique", technique)

# Transform skewed numerical features
numeric_features = all_data.select_dtypes(include=[np.number]).columns

# Calculate skewness for each numerical feature
from scipy import stats
skewed_features = all_data[numeric_features].apply(lambda x: stats.skew(x.dropna())).sort_values(ascending=False)
high_skew_features = skewed_features[skewed_features > 0.5].index

print(f"Number of highly skewed features: {len(high_skew_features)}")
mlflow.log_param("num_skewed_features", len(high_skew_features))

# Apply log transformation to highly skewed features
for feature in high_skew_features:
    # Adding 1 to avoid log(0)
    all_data[feature] = np.log1p(all_data[feature])

log_feature_eng_step("log_transform_skewed", "log1p_transform", affected_columns=high_skew_features.tolist())

# Encode categorical variables
# Ordinal encoding for quality and condition features
ordinal_quality_mapping = {
    'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5, 'None': 0, 'NA': 0
}

quality_cols = [col for col in all_data.columns if 'Qual' in col or 'Cond' in col]
quality_cols = [col for col in quality_cols if col in cat_features]

for col in quality_cols:
    all_data[col + '_Encoded'] = all_data[col].map(ordinal_quality_mapping)

log_feature_eng_step("ordinal_encoding_quality", "ordinal_mapping",
                    affected_columns=quality_cols,
                    created_columns=[col + '_Encoded' for col in quality_cols])

# One-hot encoding for other categorical features
categorical_cols = [col for col in cat_features if col not in quality_cols]
print(f"Number of categorical columns to one-hot encode: {len(categorical_cols)}")

# Apply one-hot encoding
all_data_encoded = pd.get_dummies(all_data, columns=categorical_cols, drop_first=True)
print(f"Shape after one-hot encoding: {all_data_encoded.shape}")

log_feature_eng_step("one_hot_encoding", "pd_get_dummies",
                    affected_columns=categorical_cols,
                    created_columns=[col for col in all_data_encoded.columns if col not in all_data.columns])

# Create new features
# Total square footage
all_data_encoded['TotalSF'] = all_data_encoded['1stFlrSF'] + all_data_encoded['2ndFlrSF'] + all_data_encoded['TotalBsmtSF']
log_feature_eng_step("total_square_feet", "sum_areas",
                    affected_columns=['1stFlrSF', '2ndFlrSF', 'TotalBsmtSF'],
                    created_columns=['TotalSF'])

# Total bathrooms
all_data_encoded['TotalBath'] = all_data_encoded['FullBath'] + 0.5 * all_data_encoded['HalfBath'] + \
                               all_data_encoded['BsmtFullBath'] + 0.5 * all_data_encoded['BsmtHalfBath']
log_feature_eng_step("total_bathrooms", "weighted_sum",
                    affected_columns=['FullBath', 'HalfBath', 'BsmtFullBath', 'BsmtHalfBath'],
                    created_columns=['TotalBath'])

# House age and when it was remodeled
all_data_encoded['Age'] = all_data_encoded['YrSold'] - all_data_encoded['YearBuilt']
all_data_encoded['Remodeled'] = (all_data_encoded['YearRemodAdd'] != all_data_encoded['YearBuilt']).astype(int)
all_data_encoded['RemodAge'] = all_data_encoded['YrSold'] - all_data_encoded['YearRemodAdd']
log_feature_eng_step("age_features", "year_differences",
                    affected_columns=['YrSold', 'YearBuilt', 'YearRemodAdd'],
                    created_columns=['Age', 'Remodeled', 'RemodAge'])

# Log features created
mlflow.log_param("num_features_before", all_data.shape[1])
mlflow.log_param("num_features_after", all_data_encoded.shape[1])
mlflow.log_param("new_features_created", all_data_encoded.shape[1] - all_data.shape[1])

# End feature engineering MLflow run
mlflow.end_run()
# Out:
# Number of highly skewed features: 26
# Number of categorical columns to one-hot encode: 33
# Shape after one-hot encoding: (2919, 230)
# 🏃 View run feature_engineering at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/8f979e457b224b8b88927596f3474b3a
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0

# %% [markdown]
# ## feature selection

# %%
# Start MLflow run for feature selection
if mlflow.active_run():
    mlflow.end_run()

mlflow.start_run(run_name="feature_selection")

# Let's first check what's happening with the indices
print(f"Original train data shape: {train_original.shape}")
print(f"Original train index range: {min(train_original.index)} to {max(train_original.index)}")
print(f"all_data_encoded shape: {all_data_encoded.shape}")
print(f"all_data_encoded index range: {min(all_data_encoded.index)} to {max(all_data_encoded.index)}")

# We need to understand the difference between train_original.index and train_idx
train_idx = train_original.index

# A better approach - use integer positions since we know train data comes first
train_rows = train_original.shape[0]
X_train_full = all_data_encoded.iloc[:train_rows].copy()
X_test = all_data_encoded.iloc[train_rows:].copy()
y_train = np.log1p(train_original['SalePrice'])  # Log transform for better model performance

# Verify the shapes are correct
print(f"X_train_full shape: {X_train_full.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
assert X_train_full.shape[0] == y_train.shape[0], "X and y have different number of samples!"

# Check for categorical columns that might cause issues
categorical_columns = X_train_full.select_dtypes(include=['object']).columns
if len(categorical_columns) > 0:
    print(f"Found categorical columns that need handling: {categorical_columns.tolist()}")
    # Create a numeric-only version of the data
    X_train_full_numeric = X_train_full.select_dtypes(include=[np.number])
    print(f"Using {X_train_full_numeric.shape[1]} numeric features for all feature selection methods")
else:
    X_train_full_numeric = X_train_full
    print("All features are already numeric")

# Check for and handle NaN values
if X_train_full_numeric.isnull().values.any():
    print(f"Found NaN values in numeric data.")
    # Count NaN values by column
    nan_counts = X_train_full_numeric.isnull().sum()
    columns_with_nan = nan_counts[nan_counts > 0]
    print(f"Columns with NaN values:\n{columns_with_nan}")

    # Identify columns that are entirely NaN
    all_nan_columns = [col for col in X_train_full_numeric.columns
                      if X_train_full_numeric[col].isnull().all()]

    if all_nan_columns:
        print(f"These columns are entirely NaN and will be dropped: {all_nan_columns}")
        X_train_full_numeric = X_train_full_numeric.drop(columns=all_nan_columns)

    # For the remaining columns with some NaN values, fill with median
    for col in X_train_full_numeric.columns:
        if X_train_full_numeric[col].isnull().any():
            X_train_full_numeric[col] = X_train_full_numeric[col].fillna(X_train_full_numeric[col].median())
            print(f"Filled NaN values in column {col} with median")

    # Verify no NaN values remain
    assert not X_train_full_numeric.isnull().values.any(), "NaN values still present after filling"
    print("All NaN values have been handled")

# Correlation with target variable
correlation_method = {}

# Add SalePrice back for correlation calculation
X_train_with_target = X_train_full_numeric.copy()
X_train_with_target['SalePrice'] = train_original['SalePrice']

# Calculate correlation using only numeric data
correlation = X_train_with_target.corr()['SalePrice'].sort_values(ascending=False)

# Select features with absolute correlation > threshold
thresholds = [0.1, 0.2, 0.3]
for threshold in thresholds:
    corr_selected = correlation[abs(correlation) > threshold].index.tolist()
    corr_selected.remove('SalePrice')  # Remove target
    correlation_method[f"corr_{threshold}"] = corr_selected
    print(f"Selected {len(corr_selected)} features using correlation threshold {threshold}")
    mlflow.log_param(f"num_features_corr_{threshold}", len(corr_selected))

# Lasso feature selection
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# Use numeric-only data for Lasso
lasso_selector = SelectFromModel(Lasso(alpha=0.005, random_state=42))
lasso_selector.fit(X_train_full_numeric, y_train)

lasso_selected = X_train_full_numeric.columns[lasso_selector.get_support()].tolist()
print(f"Selected {len(lasso_selected)} features using Lasso")
mlflow.log_param("num_features_lasso", len(lasso_selected))

# Random Forest feature importance
from sklearn.ensemble import RandomForestRegressor

# Use numeric-only data for Random Forest
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train_full_numeric, y_train)

# Get feature importances
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

# Select top features by importance
rf_selected_top30 = X_train_full_numeric.columns[indices[:min(30, len(indices))]].tolist()
rf_selected_top50 = X_train_full_numeric.columns[indices[:min(50, len(indices))]].tolist()

print(f"Selected top 30 features using Random Forest importance")
print(f"Selected top 50 features using Random Forest importance")
mlflow.log_param("num_features_rf_top30", len(rf_selected_top30))
mlflow.log_param("num_features_rf_top50", len(rf_selected_top50))

# Create different feature sets for experimentation
feature_sets = {
    'all_features_numeric': X_train_full_numeric.columns.tolist(),
    'corr_0.1': correlation_method['corr_0.1'],
    'corr_0.3': correlation_method['corr_0.3'],
    'lasso_selected': lasso_selected,
    'rf_top30': rf_selected_top30,
    'rf_top50': rf_selected_top50
}

# Log feature sets
for set_name, features in feature_sets.items():
    mlflow.log_param(f"feature_set_{set_name}_count", len(features))

# End feature selection MLflow run
mlflow.end_run()
# Out:
# Original train data shape: (1460, 81)
# Original train index range: 0 to 1459
# all_data_encoded shape: (2919, 235)
# all_data_encoded index range: 0 to 1459
# X_train_full shape: (1460, 235)
# y_train shape: (1460,)
# X_test shape: (1459, 235)
# Found categorical columns that need handling: ['Condition1', 'Condition2', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'KitchenQual', 'GarageQual', 'GarageCond', 'SaleCondition']
# Using 52 numeric features for all feature selection methods
# Found NaN values in numeric data.
# Columns with NaN values:
# Condition1_Encoded       1460
# Condition2_Encoded       1460
# SaleCondition_Encoded    1460
# dtype: int64
# These columns are entirely NaN and will be dropped: ['Condition1_Encoded', 'Condition2_Encoded', 'SaleCondition_Encoded']
# All NaN values have been handled
# Selected 35 features using correlation threshold 0.1
# Selected 29 features using correlation threshold 0.2
# Selected 23 features using correlation threshold 0.3
# Selected 23 features using Lasso
# Selected top 30 features using Random Forest importance
# Selected top 50 features using Random Forest importance
# 🏃 View run feature_selection at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/ad75d5e37b01426c9f60f722113550f4
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0

# %% [markdown]
# ## training

# %%
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
import numpy as np

# Define evaluation function
def rmse_cv(model, X, y, cv=5):
    kf = KFold(n_splits=cv, shuffle=True, random_state=42)
    rmse = np.sqrt(-cross_val_score(model, X, y,
                                   scoring="neg_mean_squared_error",
                                   cv=kf))
    return rmse

# Train models on different feature sets
for set_name, features in feature_sets.items():
    print(f"\nTraining models using feature set: {set_name} with {len(features)} features")

    # Prepare this feature set
    X = X_train_full[features]

    # Start MLflow run for this feature set
    with mlflow.start_run(run_name=f"model_training_{set_name}"):
        mlflow.log_param("feature_set", set_name)
        mlflow.log_param("num_features", len(features))

        # Linear Regression (baseline)
        with mlflow.start_run(run_name="linear_regression", nested=True):
            lr = LinearRegression()
            rmse = rmse_cv(lr, X, y_train).mean()
            print(f"Linear Regression RMSE: {rmse:.4f}")

            mlflow.log_param("model_type", "LinearRegression")
            mlflow.log_metric("rmse_cv", rmse)

            # Fit on full training data
            lr.fit(X, y_train)
            mlflow.sklearn.log_model(lr, "model", input_example=X.iloc[:5])

            # Check for overfitting
            train_pred = lr.predict(X)
            train_rmse = np.sqrt(mean_squared_error(y_train, train_pred))
            mlflow.log_metric("train_rmse", train_rmse)
            mlflow.log_metric("overfitting_ratio", train_rmse/rmse)

            print(f"  Train RMSE: {train_rmse:.4f}")
            print(f"  Overfitting ratio: {train_rmse/rmse:.4f}")

        # Random Forest with different parameters
        # Try different values for n_estimators and max_depth
        n_estimators_list = [50, 100, 200]
        max_depth_list = [None, 10, 20, 30]

        for n_est in n_estimators_list:
            for max_d in max_depth_list:
                with mlflow.start_run(run_name=f"rf_nest_{n_est}_depth_{max_d}", nested=True):
                    rf = RandomForestRegressor(n_estimators=n_est, max_depth=max_d, random_state=42)
                    rmse = rmse_cv(rf, X, y_train).mean()
                    print(f"Random Forest (n_est={n_est}, max_depth={max_d}) RMSE: {rmse:.4f}")

                    mlflow.log_param("model_type", "RandomForest")
                    mlflow.log_param("n_estimators", n_est)
                    mlflow.log_param("max_depth", max_d)
                    mlflow.log_metric("rmse_cv", rmse)

                    # Fit on full training data
                    rf.fit(X, y_train)
                    mlflow.sklearn.log_model(rf, "model", input_example=X.iloc[:5])

                    # Check for overfitting
                    train_pred = rf.predict(X)
                    train_rmse = np.sqrt(mean_squared_error(y_train, train_pred))
                    mlflow.log_metric("train_rmse", train_rmse)
                    mlflow.log_metric("overfitting_ratio", train_rmse/rmse)

                    print(f"  Train RMSE: {train_rmse:.4f}")
                    print(f"  Overfitting ratio: {train_rmse/rmse:.4f}")

        # XGBoost with different parameters
        # Try different learning rates, max_depths, and n_estimators
        learning_rates = [0.01, 0.05, 0.1]
        max_depths = [3, 5, 7]
        n_estimators = [100, 200]

        for lr in learning_rates:
            for depth in max_depths:
                for n_est in n_estimators:
                    with mlflow.start_run(run_name=f"xgb_lr_{lr}_depth_{depth}_nest_{n_est}", nested=True):
                        xgb_model = xgb.XGBRegressor(
                            objective='reg:squarederror',
                            learning_rate=lr,
                            max_depth=depth,
                            n_estimators=n_est,
                            random_state=42
                        )

                        rmse = rmse_cv(xgb_model, X, y_train).mean()
                        print(f"XGBoost (lr={lr}, depth={depth}, n_est={n_est}) RMSE: {rmse:.4f}")

                        mlflow.log_param("model_type", "XGBoost")
                        mlflow.log_param("learning_rate", lr)
                        mlflow.log_param("max_depth", depth)
                        mlflow.log_param("n_estimators", n_est)
                        mlflow.log_metric("rmse_cv", rmse)

                        # Fit on full training data
                        xgb_model.fit(X, y_train)
                        mlflow.xgboost.log_model(xgb_model, "model", input_example=X.iloc[:5])

                        # Check for overfitting
                        train_pred = xgb_model.predict(X)
                        train_rmse = np.sqrt(mean_squared_error(y_train, train_pred))
                        mlflow.log_metric("train_rmse", train_rmse)
                        mlflow.log_metric("overfitting_ratio", train_rmse/rmse)

                        print(f"  Train RMSE: {train_rmse:.4f}")
                        print(f"  Overfitting ratio: {train_rmse/rmse:.4f}")

# More detailed hyperparameter tuning for XGBoost
# We'll assume 'rf_top50' was one of the better feature sets
best_features = feature_sets['rf_top50']
X_best = X_train_full[best_features]

with mlflow.start_run(run_name="xgboost_hyperparameter_tuning"):
    mlflow.log_param("feature_set", "rf_top50")
    mlflow.log_param("model_type", "XGBoost")

    param_grid = {
        'learning_rate': [0.01, 0.05, 0.1],
        'n_estimators': [100, 200],
        'max_depth': [3, 5, 7],
        'min_child_weight': [1, 3, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0]
    }

    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)
    grid_search = GridSearchCV(estimator=xgb_model,
                               param_grid=param_grid,
                               scoring='neg_mean_squared_error',
                               cv=5,
                               verbose=1)

    grid_search.fit(X_best, y_train)

    # Log best parameters and score
    print(f"Best parameters: {grid_search.best_params_}")
    print(f"Best RMSE: {np.sqrt(-grid_search.best_score_):.4f}")

    for param, value in grid_search.best_params_.items():
        mlflow.log_param(f"best_{param}", value)

    mlflow.log_metric("best_rmse", np.sqrt(-grid_search.best_score_))

    # Log best model
    best_model = grid_search.best_estimator_
    mlflow.xgboost.log_model(best_model, "best_model")

    # Check for overfitting on the best model
    train_pred = best_model.predict(X_best)
    train_rmse = np.sqrt(mean_squared_error(y_train, train_pred))
    mlflow.log_metric("train_rmse", train_rmse)
    mlflow.log_metric("overfitting_ratio", train_rmse/np.sqrt(-grid_search.best_score_))

    print(f"Best model train RMSE: {train_rmse:.4f}")
    print(f"Best model overfitting ratio: {train_rmse/np.sqrt(-grid_search.best_score_):.4f}")

    # Register model in MLflow Model Registry
    mlflow.xgboost.log_model(
        best_model,
        "best_model",
        input_example=X_best.iloc[:5],
        registered_model_name="house_price_xgboost"
    )
# Out:
# Training models using feature set: all_features_numeric with 49 features
# Linear Regression RMSE: 0.1411
#   Train RMSE: 0.1320
#   Overfitting ratio: 0.9361
# 🏃 View run linear_regression at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/c119bfe1915140e7b1d613e38ec918ab
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=None) RMSE: 0.1469
#   Train RMSE: 0.0573
#   Overfitting ratio: 0.3899
# 🏃 View run rf_nest_50_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/aabd007194074bf3a18afb48cc5ddcf7
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=10) RMSE: 0.1474
#   Train RMSE: 0.0676
#   Overfitting ratio: 0.4587
# 🏃 View run rf_nest_50_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/657eb27d58b2421699a88cb8bf2135b6
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=20) RMSE: 0.1466
#   Train RMSE: 0.0570
#   Overfitting ratio: 0.3887
# 🏃 View run rf_nest_50_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/6161fa4b419046d6b6dcb4869f90c8d2
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=30) RMSE: 0.1469
#   Train RMSE: 0.0573
#   Overfitting ratio: 0.3899
# 🏃 View run rf_nest_50_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/82748728b1bd42e09ff62f27a0e96478
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=None) RMSE: 0.1462
#   Train RMSE: 0.0551
#   Overfitting ratio: 0.3768
# 🏃 View run rf_nest_100_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/37bbee557ef24d1f89586d3928205e60
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=10) RMSE: 0.1467
#   Train RMSE: 0.0652
#   Overfitting ratio: 0.4441
# 🏃 View run rf_nest_100_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/bf5cb112d8604d0f911c4bc677e95ca1
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=20) RMSE: 0.1461
#   Train RMSE: 0.0548
#   Overfitting ratio: 0.3752
# 🏃 View run rf_nest_100_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/36f2a51953c34af6b7a52b408843a78f
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=30) RMSE: 0.1462
#   Train RMSE: 0.0551
#   Overfitting ratio: 0.3768
# 🏃 View run rf_nest_100_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/958c95dd8e834f81ba4655e57ac2d086
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=None) RMSE: 0.1453
#   Train RMSE: 0.0536
#   Overfitting ratio: 0.3689
# 🏃 View run rf_nest_200_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/88ea0f10c0a2422588e01003b4e6c424
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=10) RMSE: 0.1459
#   Train RMSE: 0.0644
#   Overfitting ratio: 0.4414
# 🏃 View run rf_nest_200_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/3db2d65a1a924af2bb28fc30ebd73252
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=20) RMSE: 0.1452
#   Train RMSE: 0.0536
#   Overfitting ratio: 0.3692
# 🏃 View run rf_nest_200_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/4caba1a5952b402eb077b6a65c38adc9
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=30) RMSE: 0.1453
#   Train RMSE: 0.0536
#   Overfitting ratio: 0.3689
# 🏃 View run rf_nest_200_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/57d3b26385c24565af719632582bc939
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=3, n_est=100) RMSE: 0.2330
#   Train RMSE: 0.2238
#   Overfitting ratio: 0.9603
# 🏃 View run xgb_lr_0.01_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/b43d7de2aa144250856e99f03f526b49
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=3, n_est=200) RMSE: 0.1746
#   Train RMSE: 0.1563
#   Overfitting ratio: 0.8952
# 🏃 View run xgb_lr_0.01_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/e163c26db34c4440aa8448404ec7060c
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=5, n_est=100) RMSE: 0.2212
#   Train RMSE: 0.1951
#   Overfitting ratio: 0.8819
# 🏃 View run xgb_lr_0.01_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/6b78dcc3a73e471c875fccf997571c1b
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=5, n_est=200) RMSE: 0.1660
#   Train RMSE: 0.1181
#   Overfitting ratio: 0.7115
# 🏃 View run xgb_lr_0.01_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/ce2d54cbedb54e5287cc1083e7960ab7
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=7, n_est=100) RMSE: 0.2206
#   Train RMSE: 0.1793
#   Overfitting ratio: 0.8128
# 🏃 View run xgb_lr_0.01_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/4b1413736e2b4275b7e893d1fd97ec80
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=7, n_est=200) RMSE: 0.1700
#   Train RMSE: 0.0929
#   Overfitting ratio: 0.5467
# 🏃 View run xgb_lr_0.01_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/7038e8485fe1462cb32a437df71686c4
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=3, n_est=100) RMSE: 0.1429
#   Train RMSE: 0.1063
#   Overfitting ratio: 0.7441
# 🏃 View run xgb_lr_0.05_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/7ad11ba5c2cf454c8460c9701f28c4e0
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=3, n_est=200) RMSE: 0.1399
#   Train RMSE: 0.0915
#   Overfitting ratio: 0.6539
# 🏃 View run xgb_lr_0.05_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/5e4eff53cc1c404b82ec07bd874a76a1
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=5, n_est=100) RMSE: 0.1435
#   Train RMSE: 0.0677
#   Overfitting ratio: 0.4717
# 🏃 View run xgb_lr_0.05_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/ed62d1a8555240119c3a6c5e0a9c5170
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=5, n_est=200) RMSE: 0.1422
#   Train RMSE: 0.0523
#   Overfitting ratio: 0.3674
# 🏃 View run xgb_lr_0.05_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/5a9f96e24f644edaaa07aba973600179
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=7, n_est=100) RMSE: 0.1516
#   Train RMSE: 0.0343
#   Overfitting ratio: 0.2265
# 🏃 View run xgb_lr_0.05_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/3491c91ed3924a228197805dae7b3a27
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=7, n_est=200) RMSE: 0.1504
#   Train RMSE: 0.0201
#   Overfitting ratio: 0.1337
# 🏃 View run xgb_lr_0.05_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/b066eaeb2671434a9ac4cd8ea2135d41
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=3, n_est=100) RMSE: 0.1392
#   Train RMSE: 0.0918
#   Overfitting ratio: 0.6597
# 🏃 View run xgb_lr_0.1_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/b1f485b0944c4dc489ceb5e78d6e373d
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=3, n_est=200) RMSE: 0.1382
#   Train RMSE: 0.0764
#   Overfitting ratio: 0.5531
# 🏃 View run xgb_lr_0.1_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/8e6f4d8b08a348a8b05f387514f66dd3
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=5, n_est=100) RMSE: 0.1426
#   Train RMSE: 0.0520
#   Overfitting ratio: 0.3648
# 🏃 View run xgb_lr_0.1_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/d9d160d0eed348b8afad757063470941
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=5, n_est=200) RMSE: 0.1424
#   Train RMSE: 0.0336
#   Overfitting ratio: 0.2362
# 🏃 View run xgb_lr_0.1_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/b2239a3c5ad04414b8e4bd4a771da093
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=7, n_est=100) RMSE: 0.1494
#   Train RMSE: 0.0206
#   Overfitting ratio: 0.1382
# 🏃 View run xgb_lr_0.1_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/9d23394af937497bb635615047497675
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=7, n_est=200) RMSE: 0.1492
#   Train RMSE: 0.0080
#   Overfitting ratio: 0.0536
# 🏃 View run xgb_lr_0.1_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/967bdb60a33a484687a72836838cbe5b
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# 🏃 View run model_training_all_features_numeric at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/284ecff601b94ecf95964a1069b82342
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
#
# Training models using feature set: corr_0.1 with 35 features
# Linear Regression RMSE: 0.1461
#   Train RMSE: 0.1401
#   Overfitting ratio: 0.9590
# 🏃 View run linear_regression at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/c365d440995748ad97a934fa77d6bb4a
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=None) RMSE: 0.1496
#   Train RMSE: 0.0582
#   Overfitting ratio: 0.3892
# 🏃 View run rf_nest_50_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/2d54dd1e4d1e40a2b65aad425b90b65c
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=10) RMSE: 0.1500
#   Train RMSE: 0.0685
#   Overfitting ratio: 0.4570
# 🏃 View run rf_nest_50_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/b0ab92830ad646dcb51f6cd99fe9baaa
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=20) RMSE: 0.1494
#   Train RMSE: 0.0577
#   Overfitting ratio: 0.3864
# 🏃 View run rf_nest_50_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/239d2500c1ba4493b07fa4a5d45ffc02
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=30) RMSE: 0.1496
#   Train RMSE: 0.0582
#   Overfitting ratio: 0.3892
# 🏃 View run rf_nest_50_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/2766f38e323041f58217e363ebbbec98
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=None) RMSE: 0.1489
#   Train RMSE: 0.0559
#   Overfitting ratio: 0.3751
# 🏃 View run rf_nest_100_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/23cb7c45e34b4ef7a936f834546f9038
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=10) RMSE: 0.1494
#   Train RMSE: 0.0669
#   Overfitting ratio: 0.4478
# 🏃 View run rf_nest_100_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/9e2007e6ae134fa5a36f23e56fb9c5e2
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=20) RMSE: 0.1488
#   Train RMSE: 0.0556
#   Overfitting ratio: 0.3735
# 🏃 View run rf_nest_100_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/be4e365d9e144f17b459c33aac3a86ff
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=30) RMSE: 0.1489
#   Train RMSE: 0.0559
#   Overfitting ratio: 0.3751
# 🏃 View run rf_nest_100_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/101d3b3cd0934c0d9c5975e315779fe5
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=None) RMSE: 0.1481
#   Train RMSE: 0.0545
#   Overfitting ratio: 0.3681
# 🏃 View run rf_nest_200_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/9c1460514f394a71a5e1124b78c90238
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=10) RMSE: 0.1488
#   Train RMSE: 0.0660
#   Overfitting ratio: 0.4436
# 🏃 View run rf_nest_200_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/39f2fa6842384027bc6fba16db0c36f6
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=20) RMSE: 0.1481
#   Train RMSE: 0.0546
#   Overfitting ratio: 0.3683
# 🏃 View run rf_nest_200_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/c3a2416209bd4d60986aaff2651dff0e
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=30) RMSE: 0.1481
#   Train RMSE: 0.0545
#   Overfitting ratio: 0.3682
# 🏃 View run rf_nest_200_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/e82506cab4c548ed828c7b77364630a0
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=3, n_est=100) RMSE: 0.2326
#   Train RMSE: 0.2239
#   Overfitting ratio: 0.9626
# 🏃 View run xgb_lr_0.01_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/dbf69666093c461ead457629a6399017
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=3, n_est=200) RMSE: 0.1745
#   Train RMSE: 0.1574
#   Overfitting ratio: 0.9024
# 🏃 View run xgb_lr_0.01_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/22f4faeeab50426ab938736926e36a2b
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=5, n_est=100) RMSE: 0.2183
#   Train RMSE: 0.1961
#   Overfitting ratio: 0.8981
# 🏃 View run xgb_lr_0.01_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/ab9ad573aa10436290e3295aa41958c1
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=5, n_est=200) RMSE: 0.1644
#   Train RMSE: 0.1203
#   Overfitting ratio: 0.7315
# 🏃 View run xgb_lr_0.01_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/c1d8e77b8ef749aaaec22a491acf73e7
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=7, n_est=100) RMSE: 0.2167
#   Train RMSE: 0.1807
#   Overfitting ratio: 0.8339
# 🏃 View run xgb_lr_0.01_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/3eab3d3a75cb4117b64da361bff31edb
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=7, n_est=200) RMSE: 0.1674
#   Train RMSE: 0.0959
#   Overfitting ratio: 0.5729
# 🏃 View run xgb_lr_0.01_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/70803420010a4ace8410ef661a8a6eb3
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=3, n_est=100) RMSE: 0.1458
#   Train RMSE: 0.1115
#   Overfitting ratio: 0.7648
# 🏃 View run xgb_lr_0.05_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/2619adb6fe3d4e0d865e970e96376212
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=3, n_est=200) RMSE: 0.1453
#   Train RMSE: 0.0980
#   Overfitting ratio: 0.6748
# 🏃 View run xgb_lr_0.05_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/a77e9b8ec9c041179fdc325ea3797712
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=5, n_est=100) RMSE: 0.1457
#   Train RMSE: 0.0726
#   Overfitting ratio: 0.4987
# 🏃 View run xgb_lr_0.05_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/c15004596c2a48d2ae5366f5daeafac7
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=5, n_est=200) RMSE: 0.1462
#   Train RMSE: 0.0575
#   Overfitting ratio: 0.3936
# 🏃 View run xgb_lr_0.05_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/b75875671ae04a7ab94550a80d0d55ae
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=7, n_est=100) RMSE: 0.1517
#   Train RMSE: 0.0389
#   Overfitting ratio: 0.2562
# 🏃 View run xgb_lr_0.05_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/70ba2ad608b440db9814c4614262464c
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=7, n_est=200) RMSE: 0.1516
#   Train RMSE: 0.0251
#   Overfitting ratio: 0.1659
# 🏃 View run xgb_lr_0.05_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/90886f059d2a47dbbef0585ea19be456
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=3, n_est=100) RMSE: 0.1446
#   Train RMSE: 0.0978
#   Overfitting ratio: 0.6765
# 🏃 View run xgb_lr_0.1_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/a55eef93a9704b04a217f7aecb420ec7
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=3, n_est=200) RMSE: 0.1450
#   Train RMSE: 0.0818
#   Overfitting ratio: 0.5644
# 🏃 View run xgb_lr_0.1_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/d78af75f12de48bd8c3a5fcf69e5f8c4
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=5, n_est=100) RMSE: 0.1467
#   Train RMSE: 0.0592
#   Overfitting ratio: 0.4040
# 🏃 View run xgb_lr_0.1_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/e450df2410cd4382ba67c3426e5bea70
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=5, n_est=200) RMSE: 0.1479
#   Train RMSE: 0.0378
#   Overfitting ratio: 0.2555
# 🏃 View run xgb_lr_0.1_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/35bc4a4ea274404580d76e8dcfad6350
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=7, n_est=100) RMSE: 0.1528
#   Train RMSE: 0.0244
#   Overfitting ratio: 0.1595
# 🏃 View run xgb_lr_0.1_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/e17239764e4644a08d82e3b898b46b20
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=7, n_est=200) RMSE: 0.1531
#   Train RMSE: 0.0098
#   Overfitting ratio: 0.0641
# 🏃 View run xgb_lr_0.1_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/b4ecd5a8daed4f858b9df31372aa094a
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# 🏃 View run model_training_corr_0.1 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/89edd75f1b2940d785b44f4e08258fe3
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
#
# Training models using feature set: corr_0.3 with 23 features
# Linear Regression RMSE: 0.1499
#   Train RMSE: 0.1452
#   Overfitting ratio: 0.9686
# 🏃 View run linear_regression at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/517b76cdcce64ffabca952e9ea36fd32
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=None) RMSE: 0.1533
#   Train RMSE: 0.0590
#   Overfitting ratio: 0.3849
# 🏃 View run rf_nest_50_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/a39911d4f77e4fa1af8cbcbee94af700
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=10) RMSE: 0.1538
#   Train RMSE: 0.0715
#   Overfitting ratio: 0.4647
# 🏃 View run rf_nest_50_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/eac1ea48f7d94041831159386ae6bbce
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=20) RMSE: 0.1529
#   Train RMSE: 0.0593
#   Overfitting ratio: 0.3876
# 🏃 View run rf_nest_50_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/90e047e7c9854ea0982cc47151359008
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=30) RMSE: 0.1533
#   Train RMSE: 0.0590
#   Overfitting ratio: 0.3849
# 🏃 View run rf_nest_50_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/cf22b8d1b0684158a7b587f13be50526
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=None) RMSE: 0.1530
#   Train RMSE: 0.0570
#   Overfitting ratio: 0.3725
# 🏃 View run rf_nest_100_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/bb6edfb0e5cb4d7fa6a7d49ea389acd4
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=10) RMSE: 0.1535
#   Train RMSE: 0.0697
#   Overfitting ratio: 0.4540
# 🏃 View run rf_nest_100_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/ab7aa70f166d4e3684e26d1bcd5ff5ca
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=20) RMSE: 0.1527
#   Train RMSE: 0.0571
#   Overfitting ratio: 0.3741
# 🏃 View run rf_nest_100_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/f233d5cd5ce84a7aae6eb66178b33f6f
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=30) RMSE: 0.1530
#   Train RMSE: 0.0570
#   Overfitting ratio: 0.3725
# 🏃 View run rf_nest_100_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/8bbc0fde45b34db2a894cb238685e85c
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=None) RMSE: 0.1520
#   Train RMSE: 0.0558
#   Overfitting ratio: 0.3669
# 🏃 View run rf_nest_200_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/b3495f45cddd479db979ef5009216f68
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=10) RMSE: 0.1527
#   Train RMSE: 0.0687
#   Overfitting ratio: 0.4502
# 🏃 View run rf_nest_200_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/40d874d9572e49f2a7c822078c87e63a
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=20) RMSE: 0.1520
#   Train RMSE: 0.0559
#   Overfitting ratio: 0.3675
# 🏃 View run rf_nest_200_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/75306a1a44c14c10973d7468d8d81876
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=30) RMSE: 0.1520
#   Train RMSE: 0.0558
#   Overfitting ratio: 0.3669
# 🏃 View run rf_nest_200_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/cb7a896324574f4ba794ee7b6c877d98
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=3, n_est=100) RMSE: 0.2328
#   Train RMSE: 0.2245
#   Overfitting ratio: 0.9645
# 🏃 View run xgb_lr_0.01_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/76c9cd0093f84f72b68afa054a25eab5
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=3, n_est=200) RMSE: 0.1752
#   Train RMSE: 0.1593
#   Overfitting ratio: 0.9096
# 🏃 View run xgb_lr_0.01_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/f6b2b2611cc5461fa87b22fd270a137a
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=5, n_est=100) RMSE: 0.2198
#   Train RMSE: 0.1977
#   Overfitting ratio: 0.8995
# 🏃 View run xgb_lr_0.01_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/fbeb05efb3d84d4aa388c450c4d4aa32
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=5, n_est=200) RMSE: 0.1665
#   Train RMSE: 0.1243
#   Overfitting ratio: 0.7469
# 🏃 View run xgb_lr_0.01_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/9f51f7d8fbb84a6294997b53dc4349b1
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=7, n_est=100) RMSE: 0.2191
#   Train RMSE: 0.1825
#   Overfitting ratio: 0.8332
# 🏃 View run xgb_lr_0.01_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/61c09cd1e3aa47bab1d4f5f37c5c3923
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=7, n_est=200) RMSE: 0.1708
#   Train RMSE: 0.0996
#   Overfitting ratio: 0.5832
# 🏃 View run xgb_lr_0.01_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/09657003bd27471a8e115783da1d5a5a
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=3, n_est=100) RMSE: 0.1488
#   Train RMSE: 0.1153
#   Overfitting ratio: 0.7752
# 🏃 View run xgb_lr_0.05_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/5fbe418495dd49d08c05049e709f7cd4
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=3, n_est=200) RMSE: 0.1477
#   Train RMSE: 0.1029
#   Overfitting ratio: 0.6970
# 🏃 View run xgb_lr_0.05_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/e4c286e680be4713bd9b9b750c32b029
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=5, n_est=100) RMSE: 0.1498
#   Train RMSE: 0.0815
#   Overfitting ratio: 0.5444
# 🏃 View run xgb_lr_0.05_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/8018e55fe46f4a6995c4accd8079ae28
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=5, n_est=200) RMSE: 0.1500
#   Train RMSE: 0.0660
#   Overfitting ratio: 0.4398
# 🏃 View run xgb_lr_0.05_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/dcd04de1f8df45a48664f36e7116ef7b
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=7, n_est=100) RMSE: 0.1560
#   Train RMSE: 0.0450
#   Overfitting ratio: 0.2885
# 🏃 View run xgb_lr_0.05_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/41aae638bad44327bc2a3f385fbe54df
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=7, n_est=200) RMSE: 0.1558
#   Train RMSE: 0.0274
#   Overfitting ratio: 0.1757
# 🏃 View run xgb_lr_0.05_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/973797f64cde44599b6973badcbb2feb
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=3, n_est=100) RMSE: 0.1487
#   Train RMSE: 0.1041
#   Overfitting ratio: 0.6996
# 🏃 View run xgb_lr_0.1_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/82ed742b5e764568adb38ee3a80a5304
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=3, n_est=200) RMSE: 0.1490
#   Train RMSE: 0.0896
#   Overfitting ratio: 0.6011
# 🏃 View run xgb_lr_0.1_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/6417905d0316499994159e327458d158
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=5, n_est=100) RMSE: 0.1517
#   Train RMSE: 0.0652
#   Overfitting ratio: 0.4299
# 🏃 View run xgb_lr_0.1_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/f71a5be73c744a17a8bc0b681ae019a6
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=5, n_est=200) RMSE: 0.1533
#   Train RMSE: 0.0413
#   Overfitting ratio: 0.2697
# 🏃 View run xgb_lr_0.1_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/02a1d2ed769c44098531abdc7fc4cb91
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=7, n_est=100) RMSE: 0.1554
#   Train RMSE: 0.0288
#   Overfitting ratio: 0.1851
# 🏃 View run xgb_lr_0.1_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/69237824cfb24dc99982560032d7b8f2
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=7, n_est=200) RMSE: 0.1559
#   Train RMSE: 0.0125
#   Overfitting ratio: 0.0800
# 🏃 View run xgb_lr_0.1_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/1ef27cd5b5a84f94b275e6538d7eca71
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# 🏃 View run model_training_corr_0.3 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/7ca0c3da1f994397ab6e5fae6337593f
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
#
# Training models using feature set: lasso_selected with 23 features
# Linear Regression RMSE: 0.1387
#   Train RMSE: 0.1339
#   Overfitting ratio: 0.9656
# 🏃 View run linear_regression at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/7e4d29e673f74eed889fe0cb52dfdc79
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=None) RMSE: 0.1437
#   Train RMSE: 0.0561
#   Overfitting ratio: 0.3901
# 🏃 View run rf_nest_50_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/2c298dd2c9234d7c885e718256854850
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=10) RMSE: 0.1441
#   Train RMSE: 0.0677
#   Overfitting ratio: 0.4696
# 🏃 View run rf_nest_50_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/45ac0372305a408ebdf4305ddb6350f6
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=20) RMSE: 0.1436
#   Train RMSE: 0.0563
#   Overfitting ratio: 0.3922
# 🏃 View run rf_nest_50_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/6e38f4e2e3774063b63118aee38368b2
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=30) RMSE: 0.1437
#   Train RMSE: 0.0561
#   Overfitting ratio: 0.3901
# 🏃 View run rf_nest_50_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/ecd6f95cf8554491bde08ebb3ece0370
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=None) RMSE: 0.1440
#   Train RMSE: 0.0535
#   Overfitting ratio: 0.3713
# 🏃 View run rf_nest_100_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/d99e7fc16f8b477b9b0eea12e3f6f670
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=10) RMSE: 0.1448
#   Train RMSE: 0.0652
#   Overfitting ratio: 0.4506
# 🏃 View run rf_nest_100_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/1835ff8193974544a3dfd1dbd57b65d4
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=20) RMSE: 0.1438
#   Train RMSE: 0.0535
#   Overfitting ratio: 0.3721
# 🏃 View run rf_nest_100_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/8428ec5321da4e649bf7551f22abd019
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=30) RMSE: 0.1440
#   Train RMSE: 0.0535
#   Overfitting ratio: 0.3713
# 🏃 View run rf_nest_100_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/c44c4ad5b6cc41329e4eb7c86a98d7e3
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=None) RMSE: 0.1433
#   Train RMSE: 0.0523
#   Overfitting ratio: 0.3648
# 🏃 View run rf_nest_200_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/e344766cb90448bd9a622f5c03680f7e
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=10) RMSE: 0.1439
#   Train RMSE: 0.0643
#   Overfitting ratio: 0.4467
# 🏃 View run rf_nest_200_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/4325bc7b64674e288b716dbfc6027f79
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=20) RMSE: 0.1431
#   Train RMSE: 0.0523
#   Overfitting ratio: 0.3658
# 🏃 View run rf_nest_200_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/271b459d01c14e27bdb8c3364bc80acc
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=30) RMSE: 0.1433
#   Train RMSE: 0.0523
#   Overfitting ratio: 0.3648
# 🏃 View run rf_nest_200_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/3774df196ecd4120883619127e76e8e7
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=3, n_est=100) RMSE: 0.2333
#   Train RMSE: 0.2246
#   Overfitting ratio: 0.9625
# 🏃 View run xgb_lr_0.01_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/cf5fd8687d20416f854a3fe775bb5dde
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=3, n_est=200) RMSE: 0.1741
#   Train RMSE: 0.1575
#   Overfitting ratio: 0.9046
# 🏃 View run xgb_lr_0.01_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/39e2b66ce46a42a88e98e018d31a8b7e
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=5, n_est=100) RMSE: 0.2184
#   Train RMSE: 0.1960
#   Overfitting ratio: 0.8971
# 🏃 View run xgb_lr_0.01_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/9175ee126ef44ca2b3a1abc4d7b377e8
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=5, n_est=200) RMSE: 0.1611
#   Train RMSE: 0.1197
#   Overfitting ratio: 0.7430
# 🏃 View run xgb_lr_0.01_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/e23470a8cc104618846758340b58a7af
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=7, n_est=100) RMSE: 0.2161
#   Train RMSE: 0.1805
#   Overfitting ratio: 0.8355
# 🏃 View run xgb_lr_0.01_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/93218e78c9434e0f8a0dc0ac489b93ff
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=7, n_est=200) RMSE: 0.1636
#   Train RMSE: 0.0954
#   Overfitting ratio: 0.5831
# 🏃 View run xgb_lr_0.01_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/0fe63d0c37724d648ea4b4e16cdf19d7
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=3, n_est=100) RMSE: 0.1408
#   Train RMSE: 0.1074
#   Overfitting ratio: 0.7627
# 🏃 View run xgb_lr_0.05_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/33e27da172964ff4b330df89597c9ad8
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=3, n_est=200) RMSE: 0.1366
#   Train RMSE: 0.0928
#   Overfitting ratio: 0.6792
# 🏃 View run xgb_lr_0.05_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/36e5a285d96a43d4958fa5bdd536832f
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=5, n_est=100) RMSE: 0.1396
#   Train RMSE: 0.0720
#   Overfitting ratio: 0.5157
# 🏃 View run xgb_lr_0.05_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/01d017a5c08a46c6beaf2fe235406d80
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=5, n_est=200) RMSE: 0.1387
#   Train RMSE: 0.0577
#   Overfitting ratio: 0.4156
# 🏃 View run xgb_lr_0.05_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/4282cad8d129484e8473a0b602ca268b
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=7, n_est=100) RMSE: 0.1453
#   Train RMSE: 0.0389
#   Overfitting ratio: 0.2679
# 🏃 View run xgb_lr_0.05_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/48e5c11ce6934ba7a2d50c5d802217f8
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=7, n_est=200) RMSE: 0.1443
#   Train RMSE: 0.0254
#   Overfitting ratio: 0.1763
# 🏃 View run xgb_lr_0.05_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/2a21139fa35b4d64936b29b59fe93160
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=3, n_est=100) RMSE: 0.1368
#   Train RMSE: 0.0930
#   Overfitting ratio: 0.6801
# 🏃 View run xgb_lr_0.1_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/76ca0829823c4f26a3982fd446c425a7
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=3, n_est=200) RMSE: 0.1367
#   Train RMSE: 0.0798
#   Overfitting ratio: 0.5838
# 🏃 View run xgb_lr_0.1_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/072c80806e894ce3a476845de296218f
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=5, n_est=100) RMSE: 0.1391
#   Train RMSE: 0.0573
#   Overfitting ratio: 0.4116
# 🏃 View run xgb_lr_0.1_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/aa6b11396ac240c1be61cbc206dc54ff
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=5, n_est=200) RMSE: 0.1399
#   Train RMSE: 0.0372
#   Overfitting ratio: 0.2661
# 🏃 View run xgb_lr_0.1_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/64e5f56742ec482d9ef0239c30011749
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=7, n_est=100) RMSE: 0.1444
#   Train RMSE: 0.0257
#   Overfitting ratio: 0.1778
# 🏃 View run xgb_lr_0.1_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/1afc621f6fd240ad9da0ec9281fde21a
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=7, n_est=200) RMSE: 0.1443
#   Train RMSE: 0.0122
#   Overfitting ratio: 0.0842
# 🏃 View run xgb_lr_0.1_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/b86de2f47c534dd6bb55e9e49afaa7da
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# 🏃 View run model_training_lasso_selected at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/6cefdf4693714064bf9f47efba7ced51
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
#
# Training models using feature set: rf_top30 with 30 features
# Linear Regression RMSE: 0.1407
#   Train RMSE: 0.1350
#   Overfitting ratio: 0.9596
# 🏃 View run linear_regression at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/8c357bee444d4158b2b0f383869526a6
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=None) RMSE: 0.1467
#   Train RMSE: 0.0564
#   Overfitting ratio: 0.3848
# 🏃 View run rf_nest_50_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/cf95138a615747dd972195ed5b1fda0e
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=10) RMSE: 0.1467
#   Train RMSE: 0.0670
#   Overfitting ratio: 0.4569
# 🏃 View run rf_nest_50_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/bc8b4eb9ea334cf08cb1b2c3baee97f3
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=20) RMSE: 0.1463
#   Train RMSE: 0.0570
#   Overfitting ratio: 0.3894
# 🏃 View run rf_nest_50_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/477504e060f84faa9561cd44dcd4eab9
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=30) RMSE: 0.1466
#   Train RMSE: 0.0564
#   Overfitting ratio: 0.3849
# 🏃 View run rf_nest_50_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/fba7e4b2b7e34fd9a5a05ce6ded47125
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=None) RMSE: 0.1464
#   Train RMSE: 0.0541
#   Overfitting ratio: 0.3692
# 🏃 View run rf_nest_100_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/22ae73bc748b4123af6d0ad24671127d
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=10) RMSE: 0.1465
#   Train RMSE: 0.0646
#   Overfitting ratio: 0.4412
# 🏃 View run rf_nest_100_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/202e81306d6642fb8ed551f62df29e02
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=20) RMSE: 0.1463
#   Train RMSE: 0.0543
#   Overfitting ratio: 0.3711
# 🏃 View run rf_nest_100_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/54fcfe7cc0d24e41889e57e1d715053e
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=30) RMSE: 0.1464
#   Train RMSE: 0.0541
#   Overfitting ratio: 0.3692
# 🏃 View run rf_nest_100_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/4baa750e70cc4cbda639c7a1663f97b2
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=None) RMSE: 0.1452
#   Train RMSE: 0.0528
#   Overfitting ratio: 0.3637
# 🏃 View run rf_nest_200_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/eaa4d433552a4b949da8a98275c420eb
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=10) RMSE: 0.1456
#   Train RMSE: 0.0640
#   Overfitting ratio: 0.4394
# 🏃 View run rf_nest_200_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/5ebf1794a1ca49ef86bb25182c6825eb
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=20) RMSE: 0.1451
#   Train RMSE: 0.0530
#   Overfitting ratio: 0.3650
# 🏃 View run rf_nest_200_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/67b77f84db8b4697b83dc6d2da6c8f45
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=30) RMSE: 0.1452
#   Train RMSE: 0.0528
#   Overfitting ratio: 0.3637
# 🏃 View run rf_nest_200_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/0b17bffe065d4372bc3a97a6950c9201
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=3, n_est=100) RMSE: 0.2329
#   Train RMSE: 0.2240
#   Overfitting ratio: 0.9619
# 🏃 View run xgb_lr_0.01_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/d3c6bf133eb340308b076120d6444305
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=3, n_est=200) RMSE: 0.1742
#   Train RMSE: 0.1567
#   Overfitting ratio: 0.8997
# 🏃 View run xgb_lr_0.01_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/861a361a5ca94770b62a05e17dd8e989
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=5, n_est=100) RMSE: 0.2197
#   Train RMSE: 0.1953
#   Overfitting ratio: 0.8887
# 🏃 View run xgb_lr_0.01_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/94ae8a9fe43442d9aa61b3b814d08523
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=5, n_est=200) RMSE: 0.1636
#   Train RMSE: 0.1187
#   Overfitting ratio: 0.7254
# 🏃 View run xgb_lr_0.01_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/a92b5aa2f94d4b3386f6ea87547edcf2
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=7, n_est=100) RMSE: 0.2203
#   Train RMSE: 0.1796
#   Overfitting ratio: 0.8152
# ...
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=3, n_est=100) RMSE: 0.1419
#   Train RMSE: 0.1068
#   Overfitting ratio: 0.7528
# 🏃 View run xgb_lr_0.05_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/c72517c10da2488190133fb2a3a2cfe6
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=3, n_est=200) RMSE: 0.1393
#   Train RMSE: 0.0913
#   Overfitting ratio: 0.6557
# 🏃 View run xgb_lr_0.05_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/d062ca90f879459b981ea3b75fcdc522
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=5, n_est=100) RMSE: 0.1419
#   Train RMSE: 0.0682
#   Overfitting ratio: 0.4807
# 🏃 View run xgb_lr_0.05_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/f956e57d0057469fabb370c8d042b63d
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=5, n_est=200) RMSE: 0.1408
#   Train RMSE: 0.0522
#   Overfitting ratio: 0.3709
# 🏃 View run xgb_lr_0.05_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/f707d354102b4def81e07adfbb38a835
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=7, n_est=100) RMSE: 0.1509
#   Train RMSE: 0.0334
#   Overfitting ratio: 0.2216
# 🏃 View run xgb_lr_0.05_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/da0ee7f0f395424ab03f5d101f055600
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=7, n_est=200) RMSE: 0.1499
#   Train RMSE: 0.0182
#   Overfitting ratio: 0.1211
# 🏃 View run xgb_lr_0.05_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/6a34f7121854411f8d3969258017418c
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=3, n_est=100) RMSE: 0.1390
#   Train RMSE: 0.0920
#   Overfitting ratio: 0.6614
# 🏃 View run xgb_lr_0.1_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/527fb27bcfde485ab2edddb8eaf638be
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=3, n_est=200) RMSE: 0.1393
#   Train RMSE: 0.0753
#   Overfitting ratio: 0.5403
# 🏃 View run xgb_lr_0.1_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/a13114b77458486c9113c2dd2445f403
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=5, n_est=100) RMSE: 0.1419
#   Train RMSE: 0.0525
#   Overfitting ratio: 0.3697
# 🏃 View run xgb_lr_0.1_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/24db2d47b99c43c6b9cd321ef188a22e
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=5, n_est=200) RMSE: 0.1422
#   Train RMSE: 0.0318
#   Overfitting ratio: 0.2234
# 🏃 View run xgb_lr_0.1_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/4e8cea0f8f254dd7bb178e635ed515b7
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=7, n_est=100) RMSE: 0.1512
#   Train RMSE: 0.0176
#   Overfitting ratio: 0.1166
# 🏃 View run xgb_lr_0.1_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/a1b3b095ace04428a61063d3929acfae
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=7, n_est=200) RMSE: 0.1511
#   Train RMSE: 0.0061
#   Overfitting ratio: 0.0403
# 🏃 View run xgb_lr_0.1_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/1e5264f39e244c13aea6313209bf81d6
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# 🏃 View run model_training_rf_top30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/3e1ab83812f64cabb54e6dd9206e4d47
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
#
# Training models using feature set: rf_top50 with 49 features
# Linear Regression RMSE: 0.1411
#   Train RMSE: 0.1320
#   Overfitting ratio: 0.9361
# 🏃 View run linear_regression at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/fa35fa61b90f464b91dbaeda69edb42c
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=None) RMSE: 0.1465
#   Train RMSE: 0.0566
#   Overfitting ratio: 0.3866
# 🏃 View run rf_nest_50_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/ec52bd4d41b34440a0ad50dd668c1fe1
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=10) RMSE: 0.1481
#   Train RMSE: 0.0673
#   Overfitting ratio: 0.4544
# 🏃 View run rf_nest_50_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/2517095dd8c949ad9b5805b5a9aa19c4
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=20) RMSE: 0.1465
#   Train RMSE: 0.0567
#   Overfitting ratio: 0.3869
# 🏃 View run rf_nest_50_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/5db4d847fade4fba91785a8023855e22
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=50, max_depth=30) RMSE: 0.1465
#   Train RMSE: 0.0566
#   Overfitting ratio: 0.3866
# 🏃 View run rf_nest_50_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/4dcf2aad05df4b22ad01836a2a4d44eb
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=None) RMSE: 0.1461
#   Train RMSE: 0.0547
#   Overfitting ratio: 0.3743
# 🏃 View run rf_nest_100_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/7ef0972425784aa0aeb387abf319648a
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=10) RMSE: 0.1470
#   Train RMSE: 0.0652
#   Overfitting ratio: 0.4437
# 🏃 View run rf_nest_100_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/df066ccbb11e4ebf84704ae516acc86a
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=20) RMSE: 0.1460
#   Train RMSE: 0.0546
#   Overfitting ratio: 0.3737
# 🏃 View run rf_nest_100_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/fb31542cf6bb44c6a3020eb0247e21fa
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=100, max_depth=30) RMSE: 0.1461
#   Train RMSE: 0.0547
#   Overfitting ratio: 0.3743
# 🏃 View run rf_nest_100_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/e5becfc1b95c48e78d448212df19de44
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=None) RMSE: 0.1453
#   Train RMSE: 0.0536
#   Overfitting ratio: 0.3689
# 🏃 View run rf_nest_200_depth_None at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/988eb14dfbc8405288858e1e5417d0a8
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=10) RMSE: 0.1461
#   Train RMSE: 0.0643
#   Overfitting ratio: 0.4400
# 🏃 View run rf_nest_200_depth_10 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/10cce2ff6d1345c7a52e1990776d0341
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=20) RMSE: 0.1452
#   Train RMSE: 0.0533
#   Overfitting ratio: 0.3671
# 🏃 View run rf_nest_200_depth_20 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/490f600473b44eaf94ce8f2ca5b8f6b7
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Random Forest (n_est=200, max_depth=30) RMSE: 0.1453
#   Train RMSE: 0.0536
#   Overfitting ratio: 0.3689
# 🏃 View run rf_nest_200_depth_30 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/bcddd8189ecd430eab33011a329cc4ae
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=3, n_est=100) RMSE: 0.2330
#   Train RMSE: 0.2238
#   Overfitting ratio: 0.9603
# 🏃 View run xgb_lr_0.01_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/dc86e895a19d417499ce0e8e9c2a76c1
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=3, n_est=200) RMSE: 0.1746
#   Train RMSE: 0.1563
#   Overfitting ratio: 0.8952
# 🏃 View run xgb_lr_0.01_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/0903c1ed2b4e422b8fdf51b7387e649e
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=5, n_est=100) RMSE: 0.2198
#   Train RMSE: 0.1951
#   Overfitting ratio: 0.8877
# 🏃 View run xgb_lr_0.01_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/ef33db90bb6749e5bf4f0ad6652bc42d
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=5, n_est=200) RMSE: 0.1642
#   Train RMSE: 0.1181
#   Overfitting ratio: 0.7193
# 🏃 View run xgb_lr_0.01_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/ed5251c1734046488353e4db01023905
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=7, n_est=100) RMSE: 0.2198
#   Train RMSE: 0.1793
#   Overfitting ratio: 0.8157
# 🏃 View run xgb_lr_0.01_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/c21ef34833df463da25711ba94c580db
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.01, depth=7, n_est=200) RMSE: 0.1688
#   Train RMSE: 0.0929
#   Overfitting ratio: 0.5504
# 🏃 View run xgb_lr_0.01_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/560c41719cc2450196d10778a45654e5
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=3, n_est=100) RMSE: 0.1428
#   Train RMSE: 0.1063
#   Overfitting ratio: 0.7448
# 🏃 View run xgb_lr_0.05_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/6da7dbfd02704b95a3d9ea678c15a829
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=3, n_est=200) RMSE: 0.1398
#   Train RMSE: 0.0915
#   Overfitting ratio: 0.6542
# 🏃 View run xgb_lr_0.05_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/e2eb0e17ffd948c0aa82564db845e5f3
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=5, n_est=100) RMSE: 0.1422
#   Train RMSE: 0.0677
#   Overfitting ratio: 0.4760
# 🏃 View run xgb_lr_0.05_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/23149e9043cb4c83ba25a569cf60b776
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=5, n_est=200) RMSE: 0.1409
#   Train RMSE: 0.0523
#   Overfitting ratio: 0.3708
# 🏃 View run xgb_lr_0.05_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/80dc4cb5519a425cb6b14e449a882e72
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=7, n_est=100) RMSE: 0.1503
#   Train RMSE: 0.0343
#   Overfitting ratio: 0.2284
# 🏃 View run xgb_lr_0.05_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/077162bfbfe64f0b9922b9cf6a68ac7d
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.05, depth=7, n_est=200) RMSE: 0.1492
#   Train RMSE: 0.0201
#   Overfitting ratio: 0.1348
# 🏃 View run xgb_lr_0.05_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/2485ad6848a84004896e239faa6054c8
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=3, n_est=100) RMSE: 0.1391
#   Train RMSE: 0.0918
#   Overfitting ratio: 0.6603
# 🏃 View run xgb_lr_0.1_depth_3_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/8c040ce1834f4479881169e4164fdabc
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=3, n_est=200) RMSE: 0.1381
#   Train RMSE: 0.0764
#   Overfitting ratio: 0.5532
# 🏃 View run xgb_lr_0.1_depth_3_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/89c7b7d63cf741b4b9791f4c3a96dddd
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=5, n_est=100) RMSE: 0.1413
#   Train RMSE: 0.0520
#   Overfitting ratio: 0.3680
# 🏃 View run xgb_lr_0.1_depth_5_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/f71ed31a3d064b87b5c21254a4aee896
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=5, n_est=200) RMSE: 0.1413
#   Train RMSE: 0.0336
#   Overfitting ratio: 0.2381
# 🏃 View run xgb_lr_0.1_depth_5_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/a441779fde7646f6be7b35d9d0d8533d
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=7, n_est=100) RMSE: 0.1475
#   Train RMSE: 0.0206
#   Overfitting ratio: 0.1400
# 🏃 View run xgb_lr_0.1_depth_7_nest_100 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/79b21fd416f54ac3ba779c8bce8a3872
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# XGBoost (lr=0.1, depth=7, n_est=200) RMSE: 0.1472
#   Train RMSE: 0.0080
#   Overfitting ratio: 0.0543
# 🏃 View run xgb_lr_0.1_depth_7_nest_200 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/87f39f496af542709bbb0943ecd1d503
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# 🏃 View run model_training_rf_top50 at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/1a81156902314c4ea57bd90072432395
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Best parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 200, 'subsample': 0.6}
# Best RMSE: 0.1320
# 2025/04/10 16:25:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Best model train RMSE: 0.0549
# Best model overfitting ratio: 0.4164
# Registered model 'house_price_xgboost' already exists. Creating a new version of this model...
# 2025/04/10 16:25:36 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: house_price_xgboost, version 2
# Created version '2' of model 'house_price_xgboost'.
# 🏃 View run xgboost_hyperparameter_tuning at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0/runs/71b58a3c56f14349b6309a50df5f0c3e
# 🧪 View experiment at: https://dagshub.com/qetibakh/ML-Homework1.mlflow/#/experiments/0
